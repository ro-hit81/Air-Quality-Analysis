# %%
import xarray as xr
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.path as mpath
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import cartopy.crs as ccrs

# %%
input_path = '../input/'
cams_data_path = input_path + '2023_August/cams_remain_data/'

ds_aq = xr.open_mfdataset(cams_data_path + '/*.nc')
ds_aq
# Out:
# /opt/anaconda3/envs/air/lib/python3.10/site-packages/dask/array/core.py:4894: PerformanceWarning: Increasing number of chunks by factor of 521
#   result = blockwise(
# /opt/anaconda3/envs/air/lib/python3.10/site-packages/dask/array/core.py:4894: PerformanceWarning: Increasing number of chunks by factor of 521
#   result = blockwise(
# /opt/anaconda3/envs/air/lib/python3.10/site-packages/dask/array/core.py:4894: PerformanceWarning: Increasing number of chunks by factor of 521
#   result = blockwise(
# /opt/anaconda3/envs/air/lib/python3.10/site-packages/dask/array/core.py:4894: PerformanceWarning: Increasing number of chunks by factor of 521
#   result = blockwise(
# /opt/anaconda3/envs/air/lib/python3.10/site-packages/dask/array/core.py:4894: PerformanceWarning: Increasing number of chunks by factor of 521
#   result = blockwise(
# /opt/anaconda3/envs/air/lib/python3.10/site-packages/dask/array/core.py:4894: PerformanceWarning: Increasing number of chunks by factor of 521
#   result = blockwise(
# /opt/anaconda3/envs/air/lib/python3.10/site-packages/dask/array/core.py:4894: PerformanceWarning: Increasing number of chunks by factor of 521
#   result = blockwise(
# /opt/anaconda3/envs/air/lib/python3.10/site-packages/dask/array/core.py:4894: PerformanceWarning: Increasing number of chunks by factor of 521
#   result = blockwise(
# /opt/anaconda3/envs/air/lib/python3.10/site-packages/dask/array/core.py:4894: PerformanceWarning: Increasing number of chunks by factor of 521
#   result = blockwise(
# /opt/anaconda3/envs/air/lib/python3.10/site-packages/dask/array/core.py:4894: PerformanceWarning: Increasing number of chunks by factor of 521
#   result = blockwise(
# /opt/anaconda3/envs/air/lib/python3.10/site-packages/dask/array/core.py:4894: PerformanceWarning: Increasing number of chunks by factor of 521
#   result = blockwise(
# <xarray.Dataset> Size: 23GB
# Dimensions:     (time: 744, lon: 1258, lat: 521)
# Coordinates:
#   * time        (time) datetime64[ns] 6kB 2023-08-01 ... 2023-08-31T23:00:00
#   * lon         (lon) float64 10kB -24.95 -24.85 -24.85 ... 44.75 44.85 44.95
#   * lat         (lat) float64 4kB 30.05 30.15 30.15 30.25 ... 71.85 71.85 71.95
# Data variables:
#     chocho      (time, lat, lon) float32 2GB dask.array<chunksize=(1, 1, 700), meta=np.ndarray>
#     co          (time, lat, lon) float32 2GB dask.array<chunksize=(744, 521, 700), meta=np.ndarray>
#     dust        (time, lat, lon) float32 2GB dask.array<chunksize=(1, 1, 700), meta=np.ndarray>
#     ecres       (time, lat, lon) float32 2GB dask.array<chunksize=(1, 1, 700), meta=np.ndarray>
#     ectot       (time, lat, lon) float32 2GB dask.array<chunksize=(1, 1, 700), meta=np.ndarray>
#     hcho        (time, lat, lon) float32 2GB dask.array<chunksize=(1, 1, 700), meta=np.ndarray>
#     nh3         (time, lat, lon) float32 2GB dask.array<chunksize=(1, 1, 700), meta=np.ndarray>
#     nmvoc       (time, lat, lon) float32 2GB dask.array<chunksize=(1, 1, 700), meta=np.ndarray>
#     no          (time, lat, lon) float32 2GB dask.array<chunksize=(1, 1, 700), meta=np.ndarray>
#     pans        (time, lat, lon) float32 2GB dask.array<chunksize=(1, 1, 700), meta=np.ndarray>
#     pmwildfire  (time, lat, lon) float32 2GB dask.array<chunksize=(1, 1, 700), meta=np.ndarray>
#     sia         (time, lat, lon) float32 2GB dask.array<chunksize=(1, 1, 700), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.7
#     Title:        CAMS European air quality interim reanalysis
#     Provider:     COPERNICUS European air quality service
#     Production:   COPERNICUS Atmosphere Monitoring Service

# %%
ds_aq_monthly = ds_aq.resample(time='ME').mean()
ds_aq_monthly = ds_aq_monthly.squeeze(drop=True)
ds_aq_monthly
# Out:
# <xarray.Dataset> Size: 31MB
# Dimensions:     (lat: 521, lon: 1258)
# Coordinates:
#   * lon         (lon) float64 10kB -24.95 -24.85 -24.85 ... 44.75 44.85 44.95
#   * lat         (lat) float64 4kB 30.05 30.15 30.15 30.25 ... 71.85 71.85 71.95
# Data variables:
#     chocho      (lat, lon) float32 3MB dask.array<chunksize=(1, 700), meta=np.ndarray>
#     co          (lat, lon) float32 3MB dask.array<chunksize=(521, 700), meta=np.ndarray>
#     dust        (lat, lon) float32 3MB dask.array<chunksize=(1, 700), meta=np.ndarray>
#     ecres       (lat, lon) float32 3MB dask.array<chunksize=(1, 700), meta=np.ndarray>
#     ectot       (lat, lon) float32 3MB dask.array<chunksize=(1, 700), meta=np.ndarray>
#     hcho        (lat, lon) float32 3MB dask.array<chunksize=(1, 700), meta=np.ndarray>
#     nh3         (lat, lon) float32 3MB dask.array<chunksize=(1, 700), meta=np.ndarray>
#     nmvoc       (lat, lon) float32 3MB dask.array<chunksize=(1, 700), meta=np.ndarray>
#     no          (lat, lon) float32 3MB dask.array<chunksize=(1, 700), meta=np.ndarray>
#     pans        (lat, lon) float32 3MB dask.array<chunksize=(1, 700), meta=np.ndarray>
#     pmwildfire  (lat, lon) float32 3MB dask.array<chunksize=(1, 700), meta=np.ndarray>
#     sia         (lat, lon) float32 3MB dask.array<chunksize=(1, 700), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.7
#     Title:        CAMS European air quality interim reanalysis
#     Provider:     COPERNICUS European air quality service
#     Production:   COPERNICUS Atmosphere Monitoring Service

# %%
canton_points = gpd.read_file('../input/canton_points.gpkg')
canton_points
# Out:
#       can_code                    can_name             can_name_up  \
# 0     ['7819']      ['Verneuil-sur-Seine']      VERNEUIL SUR SEINE
# 1     ['7903']        ['Celles-sur-Belle']        CELLES SUR BELLE
# 2     ['7904']                 ['Cerizay']                 CERIZAY
# 3     ['7907']                 ['Mauléon']                 MAULEON
# 4     ['7908']                   ['Melle']                   MELLE
# ...        ...                         ...                     ...
# 2049  ['6231']                 ['Lillers']                 LILLERS
# 2050  ['6702']              ['Bouxwiller']              BOUXWILLER
# 2051  ['6707']  ['Illkirch-Graffenstaden']  ILLKIRCH GRAFFENSTADEN
# 2052  ['7004']             ['Héricourt-2']             HERICOURT 2
# 2053  ['7006']                  ['Lure-1']                  LURE 1
#
#                  can_name_lo                   geometry
# 0         verneuil-sur-seine   POINT (1.97317 48.91519)
# 1           celles-sur-belle  POINT (-0.07842 46.30673)
# 2                    cerizay  POINT (-0.57884 46.75083)
# 3                    mauléon  POINT (-0.59815 46.96082)
# 4                      melle   POINT (-0.0345 46.13387)
# ...                      ...                        ...
# 2049                 lillers   POINT (2.52187 50.57827)
# 2050              bouxwiller   POINT (7.56718 48.72967)
# 2051  illkirch-graffenstaden    POINT (7.7295 48.49898)
# 2052             héricourt-2   POINT (6.68423 47.59104)
# 2053                  lure-1   POINT (6.43828 47.71072)
#
# [2054 rows x 5 columns]

# %%
lon = canton_points.geometry.x.values
lat = canton_points.geometry.y.values

# %%
coords = xr.DataArray(list(zip(lon, lat)), dims=["points", "dim"], coords={"dim": [0, 1]})

# %%
extended_ds_var = list(ds_aq_monthly.variables)[:-2]

values_dict = {}

for var in extended_ds_var:
    if var in ds_aq_monthly:
        values_dict[var] = ds_aq_monthly[var].sel(lon=coords[:, 0], lat=coords[:, 1], method='nearest').values
    elif var == 'aq_index':
        values_dict[var] = aq_index.sel(lon=coords[:, 0], lat=coords[:, 1], method='nearest').values

for var in extended_ds_var:
    canton_points[var] = values_dict[var].tolist()

print(canton_points.head())

# %%
canton_points.to_file('../intermediates/cams_remain_data_extracted.gpkg', driver='GPKG')
